# %%
from collections import OrderedDict
import os
import glob
import numpy as np
import pandas as pd
import dask
from dask.delayed import delayed
from dask.distributed import Client, wait
import dask.dataframe
import shutil

# %%
use_local_cuda_cluster = False
# Use below for a local-only CUDA cluster
if use_local_cuda_cluster:
    from dask_cuda import LocalCUDACluster
    cluster = LocalCUDACluster(ip='0.0.0.0')
    client = Client(cluster)

# %%
# Use below for a multi-host multi-GPU CUDA cluster started with start_dask.py.
if not use_local_cuda_cluster:
    scheduler_address = '10.200.11.12:8786'
    client = Client(address=scheduler_address)

# %%
client
# Out:
# <Client: 'tcp://172.28.10.181:8786' processes=32 threads=160, memory=2.20 TB>

# %%
# %%time
# Restart all workers. This also clears GPU memory.
client.restart()
# Out:
# distributed.client - ERROR - Restart timed out after 20.000000 seconds
# CPU times: user 22.8 ms, sys: 0 ns, total: 22.8 ms
# Wall time: 20 s
# <Client: 'tcp://172.28.10.181:8786' processes=0 threads=0, memory=0 B>

# %%
# Below from mortgage/E2E.ipynb.
def load_performance_csv(performance_path, **kwargs):
    """ Loads performance data

    Returns
    -------
    GPU DataFrame
    """
    
    cols = [
        "loan_id", "monthly_reporting_period", "servicer", "interest_rate", "current_actual_upb",
        "loan_age", "remaining_months_to_legal_maturity", "adj_remaining_months_to_maturity",
        "maturity_date", "msa", "current_loan_delinquency_status", "mod_flag", "zero_balance_code",
        "zero_balance_effective_date", "last_paid_installment_date", "foreclosed_after",
        "disposition_date", "foreclosure_costs", "prop_preservation_and_repair_costs",
        "asset_recovery_costs", "misc_holding_expenses", "holding_taxes", "net_sale_proceeds",
        "credit_enhancement_proceeds", "repurchase_make_whole_proceeds", "other_foreclosure_proceeds",
        "non_interest_bearing_upb", "principal_forgiveness_upb", "repurchase_make_whole_proceeds_flag",
        "foreclosure_principal_write_off_amount", "servicing_activity_indicator"
    ]
    
    dtypes = OrderedDict([
        ("loan_id", "int64"),
        ("monthly_reporting_period", "date"),
        ("servicer", "category"),
        ("interest_rate", "float64"),
        ("current_actual_upb", "float64"),
        ("loan_age", "float64"),
        ("remaining_months_to_legal_maturity", "float64"),
        ("adj_remaining_months_to_maturity", "float64"),
        ("maturity_date", "date"),
        ("msa", "float64"),
        ("current_loan_delinquency_status", "int32"),
        ("mod_flag", "category"),
        ("zero_balance_code", "category"),
        ("zero_balance_effective_date", "date"),
        ("last_paid_installment_date", "date"),
        ("foreclosed_after", "date"),
        ("disposition_date", "date"),
        ("foreclosure_costs", "float64"),
        ("prop_preservation_and_repair_costs", "float64"),
        ("asset_recovery_costs", "float64"),
        ("misc_holding_expenses", "float64"),
        ("holding_taxes", "float64"),
        ("net_sale_proceeds", "float64"),
        ("credit_enhancement_proceeds", "float64"),
        ("repurchase_make_whole_proceeds", "float64"),
        ("other_foreclosure_proceeds", "float64"),
        ("non_interest_bearing_upb", "float64"),
        ("principal_forgiveness_upb", "float64"),
        ("repurchase_make_whole_proceeds_flag", "category"),
        ("foreclosure_principal_write_off_amount", "float64"),
        ("servicing_activity_indicator", "category")
    ])
    dtypes = {k: ("str" if v=="date" else v) for k,v in dtypes.items()}

    return dask.dataframe.read_csv(performance_path, names=cols, delimiter='|', dtype=dtypes, blocksize=1e9)

# %%
# Identify list of files to load.
data_dir = '/mnt/isilon1/data/mortgage'
perf_file = []
perf_file += glob.glob(data_dir + '/perf/Performance_*')
#perf_file += glob.glob(data_dir + '/perf/Performance_*')
#perf_file += glob.glob(data_dir + '/perf/Performance_2016*.txt')
len(perf_file)
# Out:
# 112

# %%
# %%time
perf_ddf = load_performance_csv(perf_file)
# Out:
# CPU times: user 689 ms, sys: 0 ns, total: 689 ms
# Wall time: 698 ms

# %%
perf_ddf
# Out:
# Dask DataFrame Structure:
#                 loan_id monthly_reporting_period           servicer interest_rate current_actual_upb loan_age remaining_months_to_legal_maturity adj_remaining_months_to_maturity maturity_date      msa current_loan_delinquency_status           mod_flag  zero_balance_code zero_balance_effective_date last_paid_installment_date foreclosed_after disposition_date foreclosure_costs prop_preservation_and_repair_costs asset_recovery_costs misc_holding_expenses holding_taxes net_sale_proceeds credit_enhancement_proceeds repurchase_make_whole_proceeds other_foreclosure_proceeds non_interest_bearing_upb principal_forgiveness_upb repurchase_make_whole_proceeds_flag foreclosure_principal_write_off_amount servicing_activity_indicator
# npartitions=246
#                   int64                   object  category[unknown]       float64            float64  float64                            float64                          float64        object  float64                           int32  category[unknown]  category[unknown]                      object                     object           object           object           float64                            float64              float64               float64       float64           float64                     float64                        float64                    float64                  float64                   float64                   category[unknown]                                float64            category[unknown]
#                     ...                      ...                ...           ...                ...      ...                                ...                              ...           ...      ...                             ...                ...                ...                         ...                        ...              ...              ...               ...                                ...                  ...                   ...           ...               ...                         ...                            ...                        ...                      ...                       ...                                 ...                                    ...                          ...
# ...                 ...                      ...                ...           ...                ...      ...                                ...                              ...           ...      ...                             ...                ...                ...                         ...                        ...              ...              ...               ...                                ...                  ...                   ...           ...               ...                         ...                            ...                        ...                      ...                       ...                                 ...                                    ...                          ...
#                     ...                      ...                ...           ...                ...      ...                                ...                              ...           ...      ...                             ...                ...                ...                         ...                        ...              ...              ...               ...                                ...                  ...                   ...           ...               ...                         ...                            ...                        ...                      ...                       ...                                 ...                                    ...                          ...
#                     ...                      ...                ...           ...                ...      ...                                ...                              ...           ...      ...                             ...                ...                ...                         ...                        ...              ...              ...               ...                                ...                  ...                   ...           ...               ...                         ...                            ...                        ...                      ...                       ...                                 ...                                    ...                          ...
# Dask Name: from-delayed, 738 tasks

# %%
# %%time
perf_ddf.head()
# Out:
# CPU times: user 51.1 ms, sys: 2.79 ms, total: 53.9 ms
# Wall time: 32.8 s
#         loan_id monthly_reporting_period servicer  interest_rate  \
# 0  548637365156               01/01/2005      NaN           5.75
# 1  548637365156               01/01/2006      NaN           5.75
# 2  548637365156               01/01/2007      NaN           5.75
# 3  548637365156               02/01/2005      NaN           5.75
# 4  548637365156               02/01/2006      NaN           5.75
#
#    current_actual_upb  loan_age  remaining_months_to_legal_maturity  \
# 0           130964.67       9.0                               351.0
# 1           129125.98      21.0                               339.0
# 2           127061.77      33.0                               327.0
# 3           130820.14      10.0                               350.0
# 4           128972.64      22.0                               338.0
#
#    adj_remaining_months_to_maturity maturity_date      msa  ...  \
# 0                             351.0       04/2034  35840.0  ...
# 1                             338.0       04/2034  35840.0  ...
# 2                             325.0       04/2034  35840.0  ...
# 3                             350.0       04/2034  35840.0  ...
# 4                             337.0       04/2034  35840.0  ...
#
#    holding_taxes net_sale_proceeds credit_enhancement_proceeds  \
# 0            NaN               NaN                         NaN
# 1            NaN               NaN                         NaN
# 2            NaN               NaN                         NaN
# 3            NaN               NaN                         NaN
# 4            NaN               NaN                         NaN
#
#   repurchase_make_whole_proceeds other_foreclosure_proceeds  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
#
#   non_interest_bearing_upb principal_forgiveness_upb  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
#    repurchase_make_whole_proceeds_flag  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    foreclosure_principal_write_off_amount  servicing_activity_indicator
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3                                     NaN                           NaN
# 4                                     NaN                           NaN
#
# [5 rows x 31 columns]

# %%
to_write_ddf = perf_ddf.repartition(npartitions=16*6)
to_write_ddf
# Out:
# Dask DataFrame Structure:
#                loan_id monthly_reporting_period           servicer interest_rate current_actual_upb loan_age remaining_months_to_legal_maturity adj_remaining_months_to_maturity maturity_date      msa current_loan_delinquency_status           mod_flag  zero_balance_code zero_balance_effective_date last_paid_installment_date foreclosed_after disposition_date foreclosure_costs prop_preservation_and_repair_costs asset_recovery_costs misc_holding_expenses holding_taxes net_sale_proceeds credit_enhancement_proceeds repurchase_make_whole_proceeds other_foreclosure_proceeds non_interest_bearing_upb principal_forgiveness_upb repurchase_make_whole_proceeds_flag foreclosure_principal_write_off_amount servicing_activity_indicator
# npartitions=96
#                  int64                   object  category[unknown]       float64            float64  float64                            float64                          float64        object  float64                           int32  category[unknown]  category[unknown]                      object                     object           object           object           float64                            float64              float64               float64       float64           float64                     float64                        float64                    float64                  float64                   float64                   category[unknown]                                float64            category[unknown]
#                    ...                      ...                ...           ...                ...      ...                                ...                              ...           ...      ...                             ...                ...                ...                         ...                        ...              ...              ...               ...                                ...                  ...                   ...           ...               ...                         ...                            ...                        ...                      ...                       ...                                 ...                                    ...                          ...
# ...                ...                      ...                ...           ...                ...      ...                                ...                              ...           ...      ...                             ...                ...                ...                         ...                        ...              ...              ...               ...                                ...                  ...                   ...           ...               ...                         ...                            ...                        ...                      ...                       ...                                 ...                                    ...                          ...
#                    ...                      ...                ...           ...                ...      ...                                ...                              ...           ...      ...                             ...                ...                ...                         ...                        ...              ...              ...               ...                                ...                  ...                   ...           ...               ...                         ...                            ...                        ...                      ...                       ...                                 ...                                    ...                          ...
#                    ...                      ...                ...           ...                ...      ...                                ...                              ...           ...      ...                             ...                ...                ...                         ...                        ...              ...              ...               ...                                ...                  ...                   ...           ...               ...                         ...                            ...                        ...                      ...                       ...                                 ...                                    ...                          ...
# Dask Name: repartition, 834 tasks

# %%
import snappy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-75-710a7f18823c> in <module>
# ----> 1 import snappy
#
# ModuleNotFoundError: No module named 'snappy'

# %%
p = to_write_ddf.get_partition(0).to
p
# Out:
# Dask DataFrame Structure:
#               loan_id monthly_reporting_period           servicer interest_rate current_actual_upb loan_age remaining_months_to_legal_maturity adj_remaining_months_to_maturity maturity_date      msa current_loan_delinquency_status           mod_flag  zero_balance_code zero_balance_effective_date last_paid_installment_date foreclosed_after disposition_date foreclosure_costs prop_preservation_and_repair_costs asset_recovery_costs misc_holding_expenses holding_taxes net_sale_proceeds credit_enhancement_proceeds repurchase_make_whole_proceeds other_foreclosure_proceeds non_interest_bearing_upb principal_forgiveness_upb repurchase_make_whole_proceeds_flag foreclosure_principal_write_off_amount servicing_activity_indicator
# npartitions=1
#                 int64                   object  category[unknown]       float64            float64  float64                            float64                          float64        object  float64                           int32  category[unknown]  category[unknown]                      object                     object           object           object           float64                            float64              float64               float64       float64           float64                     float64                        float64                    float64                  float64                   float64                   category[unknown]                                float64            category[unknown]
#                   ...                      ...                ...           ...                ...      ...                                ...                              ...           ...      ...                             ...                ...                ...                         ...                        ...              ...              ...               ...                                ...                  ...                   ...           ...               ...                         ...                            ...                        ...                      ...                       ...                                 ...                                    ...                          ...
# Dask Name: get-partition, 835 tasks

# %%
def to_orc(
    df,
    path,
    compression=None,
    compute=True,
):
    """Store Dask.dataframe to ORC files

    Notes
    -----
    Each partition will be written to a separate file.

    Parameters
    ----------
    df : dask.dataframe.DataFrame
    path : string or pathlib.Path
        Destination directory for data.  Prepend with protocol like ``s3://``
        or ``hdfs://`` for remote data.
    compute : bool, optional
        If True (default) then the result is computed immediately. If False
        then a ``dask.delayed`` object is returned for future computation.
    """
    os.mkdir(path)    
    filenames = [os.path.join(path, "part.%i.orc" % i) for i in range(df.npartitions)]    
    parts = [
        dask.delayed(d.to_orc)(filename)
        for d, filename in zip(df.to_delayed(), filenames)
    ]
    out = dask.delayed(lambda x: None)(parts)    
    if compute:
        out = out.compute()
    return out

# %%
orc_dir = os.path.join(data_dir, 'perf.orc')
if os.path.exists(orc_dir): shutil.rmtree(orc_dir)
to_orc(to_write_ddf, orc_dir)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-70d47eb16f29> in <module>
#       1 orc_dir = os.path.join(data_dir, 'perf.orc')
#       2 if os.path.exists(orc_dir): shutil.rmtree(orc_dir)
# ----> 3 to_orc(to_write_ddf, orc_dir)
#
# <ipython-input-72-6a39f221f819> in to_orc(df, path, compression, compute)
#      29     out = dask.delayed(lambda x: None)(parts)
#      30     if compute:
# ---> 31         out = out.compute()
#      32     return out
#
# /opt/conda/envs/rapids/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     163         dask.base.compute
#     164         """
# --> 165         (result,) = compute(self, traverse=False, **kwargs)
#     166         return result
#     167
#
# /opt/conda/envs/rapids/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     434     keys = [x.__dask_keys__() for x in collections]
#     435     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 436     results = schedule(dsk, keys, **kwargs)
#     437     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     438
#
# /opt/conda/envs/rapids/lib/python3.6/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2543                     should_rejoin = False
#    2544             try:
# -> 2545                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2546             finally:
#    2547                 for f in futures.values():
#
# /opt/conda/envs/rapids/lib/python3.6/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1843                 direct=direct,
#    1844                 local_worker=local_worker,
# -> 1845                 asynchronous=asynchronous,
#    1846             )
#    1847
#
# /opt/conda/envs/rapids/lib/python3.6/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     760         else:
#     761             return sync(
# --> 762                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     763             )
#     764
#
# /opt/conda/envs/rapids/lib/python3.6/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     331     if error[0]:
#     332         typ, exc, tb = error[0]
# --> 333         raise exc.with_traceback(tb)
#     334     else:
#     335         return result[0]
#
# /opt/conda/envs/rapids/lib/python3.6/site-packages/distributed/utils.py in f()
#     315             if callback_timeout is not None:
#     316                 future = gen.with_timeout(timedelta(seconds=callback_timeout), future)
# --> 317             result[0] = yield future
#     318         except Exception as exc:
#     319             error[0] = sys.exc_info()
#
# /opt/conda/envs/rapids/lib/python3.6/site-packages/tornado/gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# /opt/conda/envs/rapids/lib/python3.6/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1699                             exc = CancelledError(key)
#    1700                         else:
# -> 1701                             raise exception.with_traceback(traceback)
#    1702                         raise exc
#    1703                     if errors == "skip":
#
# /opt/conda/envs/rapids/lib/python3.6/site-packages/dask/utils.py in __call__()
#     874
#     875     def __call__(self, obj, *args, **kwargs):
# --> 876         return getattr(obj, self.method)(*args, **kwargs)
#     877
#     878     def __reduce__(self):
#
# /opt/conda/envs/rapids/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__()
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_orc'
