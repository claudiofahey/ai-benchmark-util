# %%
from collections import OrderedDict
import os
import glob
import numpy as np
import pandas as pd
import dask
from dask.delayed import delayed
from dask.distributed import Client, wait
import dask_cudf
import datetime

# %%
print(datetime.datetime.utcnow().isoformat())
# Out:
# 2019-11-23T03:48:55.403003

# %%
# !cat start_dask.yaml
# Out:
# device_memory_limit_gib: 26.0
# docker_image: claudiofahey/rapidsai:a359097c3c18a534b91557d5abe772c73ef57d11de3dfb632e1516b0a01745f1
# host:
#   - 10.200.11.12
#   - 10.200.11.13
# memory_limit_gib: 64.0

# %%
use_local_cuda_cluster = False
# Use below for a local-only CUDA cluster
if use_local_cuda_cluster:
    from dask_cuda import LocalCUDACluster
    cluster = LocalCUDACluster(ip='0.0.0.0')
    client = Client(cluster)

# %%
# Use below for a multi-host multi-GPU CUDA cluster started with start_dask.py.
if not use_local_cuda_cluster:
    scheduler_address = '10.200.11.12:8786'
    client = Client(address=scheduler_address)

# %%
client
# Out:
# <Client: 'tcp://172.28.10.181:8786' processes=32 threads=160, memory=2.20 TB>

# %%
import cudf

# %%
# %%time
# Restart all workers. This also clears GPU memory.
client.restart()
# Out:
# CPU times: user 21.4 ms, sys: 336 µs, total: 21.7 ms
# Wall time: 18.7 s
# <Client: 'tcp://172.28.10.181:8786' processes=4 threads=20, memory=274.88 GB>

# %%
def gpu_load_performance_data(performance_path, **kwargs):
    """ Loads performance data

    Returns
    -------
    GPU DataFrame
    """
    
    cols = [
        "loan_id", "monthly_reporting_period", "servicer", "interest_rate", "current_actual_upb",
        "loan_age", "remaining_months_to_legal_maturity", "adj_remaining_months_to_maturity",
        "maturity_date", "msa", "current_loan_delinquency_status", "mod_flag", "zero_balance_code",
        "zero_balance_effective_date", "last_paid_installment_date", "foreclosed_after",
        "disposition_date", "foreclosure_costs", "prop_preservation_and_repair_costs",
        "asset_recovery_costs", "misc_holding_expenses", "holding_taxes", "net_sale_proceeds",
        "credit_enhancement_proceeds", "repurchase_make_whole_proceeds", "other_foreclosure_proceeds",
        "non_interest_bearing_upb", "principal_forgiveness_upb", "repurchase_make_whole_proceeds_flag",
        "foreclosure_principal_write_off_amount", "servicing_activity_indicator"
    ]

    ddf = dask_cudf.read_parquet(performance_path)
    #ddf = cudf.read_parquet(performance_path)
#     ddf = ddf.rename(columns=dict(zip(ddf.columns, cols)))
    return ddf

# %%
# Identify list of files to load.
data_dir = '/mnt/isilon1/data/mortgage'
perf_file = []
perf_file += glob.glob(data_dir + '/perf-snappy.parquet/part.0.parquet')
#perf_file += glob.glob(data_dir + '/perf/Performance_*')
#perf_file += glob.glob(data_dir + '/perf/Performance_2016*.txt')
len(perf_file)
# Out:
# 1

# %%
cudf.read_parquet(data_dir + '/perf-snappy.parquet/part.0.parquet')
# Out:
#              loan_id monthly_reporting_period     servicer  interest_rate  \
# index
# 0       100000040778               2017-01-01         null          3.875
# 1       100000040778               2017-02-01         null          3.875
# 4               233356.22      10.0                               350.0
# 5               232983.66      11.0                               349.0
# 6                    null       0.0                               360.0
# 7               232616.83      12.0                               348.0
# 8                    null       1.0                               359.0
# 9               232116.94      13.0                               347.0
# 10                   null       2.0                               358.0
# 11              231615.43      14.0                               346.0
# 12                   null       3.0                               357.0
# 13              231244.18      15.0                               345.0
# 14                   null       4.0                               356.0
# 15              230871.74      16.0                               344.0
# 16                   null       5.0                               355.0
# 17              230498.09      17.0                               343.0
# 18              124010.71       5.0                               355.0
# 19              123811.12       6.0                               354.0
# 20              123610.95       7.0                               353.0
# 21              123410.19       8.0                               352.0
# 22              123208.85       9.0                               351.0
# 23              123006.92      10.0                               350.0
# 24                   null      -1.0                               361.0
# 25               122804.4      11.0                               349.0
# 26                   null       0.0                               360.0
# 27              122601.29      12.0                               348.0
# 28                   null       1.0                               359.0
# 29              122397.59      13.0                               347.0
# ...                   ...       ...                                 ...
# 508071               null       3.0                               357.0
# 508072               null       4.0                               356.0
# 508073               null       5.0                               355.0
# 508074               null       3.0                               357.0
# 508075               null       4.0                               356.0
# 508076          413033.56       5.0                               355.0
# 508077          412365.72       6.0                               354.0
# 508078          411695.93       7.0                               353.0
# 508079          411024.19       8.0                               352.0
# 508080          410350.49       9.0                               351.0
# 508081          409674.83      10.0                               350.0
# 508082               null      -1.0                               361.0
# 508083           408997.2      11.0                               349.0
# 508084               null       0.0                               360.0
# 508085          408317.59      12.0                               348.0
# 508086               null       1.0                               359.0
# 508087           407636.0      13.0                               347.0
# 508088               null       2.0                               358.0
# 508089          406952.42      14.0                               346.0
# 508090          317085.49       6.0                               354.0
# 508091          316594.41       7.0                               353.0
# 508092          315607.65       8.0                               352.0
# 508093          315607.65       9.0                               351.0
# 508094          315111.95      10.0                               350.0
# 508095           314614.7      11.0                               349.0
# 508096               null       0.0                               360.0
# 508097           314115.9      12.0                               348.0
# 508098               null       1.0                               359.0
# 508099          313615.54      13.0                               347.0
# 508100               null       2.0                               358.0
#
#        adj_remaining_months_to_maturity       maturity_date      msa  ...  \
# index                                                                 ...
# 0                                 352.0 1910-05-25 17:31:44  40140.0  ...
# 1                                 351.0 1910-05-25 17:31:44  40140.0  ...
# 2                                 350.0 1910-05-25 17:31:44  40140.0  ...
# 3                                 349.0 1910-05-25 17:31:44  40140.0  ...
# 4                                 348.0 1910-05-25 17:31:44  40140.0  ...
# 5                                 346.0 1910-05-25 17:31:44  40140.0  ...
# 6                                 359.0 1910-05-25 17:31:44  40140.0  ...
# 7                                 345.0 1910-05-25 17:31:44  40140.0  ...
# 8                                 358.0 1910-05-25 17:31:44  40140.0  ...
# 9                                 344.0 1910-05-25 17:31:44  40140.0  ...
# 10                                357.0 1910-05-25 17:31:44  40140.0  ...
# 11                                343.0 1910-05-25 17:31:44  40140.0  ...
# 12                                356.0 1910-05-25 17:31:44  40140.0  ...
# 0                null               null                        null
# 1                null               null                        null
# 2                null               null                        null
# 3                null               null                        null
# 4                null               null                        null
# 5                null               null                        null
# 6                null               null                        null
# 7                null               null                        null
# 8                null               null                        null
# 9                null               null                        null
# 10               null               null                        null
# 11               null               null                        null
# 12               null               null                        null
# 13               null               null                        null
# 14               null               null                        null
# 15               null               null                        null
# 16               null               null                        null
# 17               null               null                        null
# 18               null               null                        null
# 19               null               null                        null
# 20               null               null                        null
# 21               null               null                        null
# 22               null               null                        null
# 23               null               null                        null
# 24               null               null                        null
# 25               null               null                        null
# 26               null               null                        null
# 27               null               null                        null
# 28               null               null                        null
# 29               null               null                        null
# ...               ...                ...                         ...
# 508071           null               null                        null
# 508072           null               null                        null
# 508073           null               null                        null
# 508074           null               null                        null
# 508075           null               null                        null
# 508076           null               null                        null
# 508077           null               null                        null
# 508078           null               null                        null
# 508079           null               null                        null
# 508080           null               null                        null
# 508081           null               null                        null
# 508082           null               null                        null
# 508083           null               null                        null
# 508084           null               null                        null
# 508085           null               null                        null
# 508086           null               null                        null
# 508087           null               null                        null
# 508088           null               null                        null
# 508089           null               null                        null
# 508090           null               null                        null
# 508091           null               null                        null
# 508092           null               null                        null
# 508093           null               null                        null
# 508094           null               null                        null
# 508095           null               null                        null
# 508096           null               null                        null
# 508097           null               null                        null
# 508098           null               null                        null
# 508099           null               null                        null
# 508100           null               null                        null
#
#        repurchase_make_whole_proceeds other_foreclosure_proceeds  \
# index
# 0                                null                       null
# 1                                null                       null
# 2                                null                       null
# 3                                null                       null
# 4                                null                       null
# 5                                null                       null
# 6                                null                       null
# 7                                null                       null
# 8                                null                       null
# 9                                null                       null
# 10                               null                       null
# 11                               null                       null
# 12                               null                       null
# 13                               null                       null
# 14                               null                       null
# 15                               null                       null
# 16                               null                       null
# 17                               null                       null
# 18                               null                       null
# 19                               null                       null
# 20                               null                       null
# 21                               null                       null
# 22                               null                       null
# 23                               null                       null
# 24                               null                       null
# 25                               null                       null
# 26                               null                       null
# 27                               null                       null
# 28                               null                       null
# 29                               null                       null
# ...                               ...                        ...
# 508071                           null                       null
# 508072                           null                       null
# 508073                           null                       null
# 508074                           null                       null
# 508075                           null                       null
# 508076                           null                       null
# 508077                           null                       null
# 508078                           null                       null
# 508079                           null                       null
# 508080                           null                       null
# 508081                           null                       null
# 508082                           null                       null
# 508083                           null                       null
# 508084                           null                       null
# 508085                           null                       null
# 508086                           null                       null
# 508087                           null                       null
# 508088                           null                       null
# 508089                           null                       null
# 508090                           null                       null
# 508091                           null                       null
# 508092                           null                       null
# 508093                           null                       null
# 508094                           null                       null
# 508095                           null                       null
# 508096                           null                       null
# 508097                           null                       null
# 508098                           null                       null
# 508099                           null                       null
# 508100                           null                       null
#
#        non_interest_bearing_upb principal_forgiveness_upb  \
# index
# 0                          null                      null
# 1                          null                      null
# 2                          null                      null
# 3                          null                      null
# 4                          null                      null
# 5                          null                      null
# 6                          null                      null
# 7                          null                      null
# 8                          null                      null
# 9                          null                      null
# 10                         null                      null
# 11                         null                      null
# 12                         null                      null
# 13                         null                      null
# 14                         null                      null
# 15                         null                      null
# 16                         null                      null
# 17                         null                      null
# 18                         null                      null
# 19                         null                      null
# 20                         null                      null
# 21                         null                      null
# 22                         null                      null
# 23                         null                      null
# 24                         null                      null
# 25                         null                      null
# 26                         null                      null
# 27                         null                      null
# 28                         null                      null
# 29                         null                      null
# ...                         ...                       ...
# 508071                     null                      null
# 508072                     null                      null
# 508073                     null                      null
# 508074                     null                      null
# 508075                     null                      null
# 508076                     null                      null
# 508077                     null                      null
# 508078                     null                      null
# 508079                     null                      null
# 508080                     null                      null
# 508081                     null                      null
# 508082                     null                      null
# 508083                     null                      null
# 508084                     null                      null
# 508085                     null                      null
# 508086                     null                      null
# 508087                     null                      null
# 508088                     null                      null
# 508089                     null                      null
# 508090                     null                      null
# 508091                     null                      null
# 508092                     null                      null
# 508093                     null                      null
# 508094                     null                      null
# 508095                     null                      null
# 508096                     null                      null
# 508097                     null                      null
# 508098                     null                      null
# 508099                     null                      null
# 508100                     null                      null
#
#        repurchase_make_whole_proceeds_flag  \
# index
# 0                                     null
# 1                                     null
# 2                                     null
# 3                                     null
# 4                                     null
# 5                                     null
# 6                                     null
# 7                                     null
# 8                                     null
# 9                                     null
# 10                                    null
# 11                                    null
# 12                                    null
# 13                                    null
# 14                                    null
# 15                                    null
# 16                                    null
# 17                                    null
# 18                                    null
# 19                                    null
# 20                                    null
# 21                                    null
# 22                                    null
# 23                                    null
# 24                                    null
# 25                                    null
# 26                                    null
# 27                                    null
# 28                                    null
# 29                                    null
# ...                                    ...
# 508071                                null
# 508072                                null
# 508073                                null
# 508074                                null
# 508075                                null
# 508076                                null
# 508077                                null
# 508078                                null
# 508079                                null
# 508080                                null
# 508081                                null
# 508082                                null
# 508083                                null
# 508084                                null
# 508085                                null
# 508086                                null
# 508087                                null
# 508088                                null
# 508089                                null
# 508090                                null
# 508091                                null
# 508092                                null
# 508093                                null
# 508094                                null
# 508095                                null
# 508096                                null
# 508097                                null
# 508098                                null
# 508099                                null
# 508100                                null
#
#        foreclosure_principal_write_off_amount servicing_activity_indicator
# index
# 0                                        null                      2313200
# 1                                        null                      2313200
# 2                                        null                      2313200
# 3                                        null                    933513450
# 4                                        null                      2313200
# 5                                        null                      2313200
# 6                                        null                      2313200
# 7                                        null                      2313200
# 8                                        null                      2313200
# 9                                        null                      2313200
# 10                                       null                      2313200
# 11                                       null                    933513450
# 12                                       null                      2313200
# 13                                       null                      2313200
# 14                                       null                      2313200
# 15                                       null                      2313200
# 16                                       null                      2313200
# 17                                       null                      2313200
# 18                                       null                      2313200
# 19                                       null                      2313200
# 20                                       null                      2313200
# 21                                       null                      2313200
# 22                                       null                      2313200
# 23                                       null                      2313200
# 24                                       null                      2313200
# 25                                       null                      2313200
# 26                                       null                      2313200
# 27                                       null                      2313200
# 28                                       null                      2313200
# 29                                       null                      2313200
# ...                                       ...                          ...
# 508071                                   null                      2313200
# 508072                                   null                      2313200
# 508073                                   null                      2313200
# 508074                                   null                      2313200
# 508075                                   null                      2313200
# 508076                                   null                      2313200
# 508077                                   null                      2313200
# 508078                                   null                      2313200
# 508079                                   null                      2313200
# 508080                                   null                      2313200
# 508081                                   null                      2313200
# 508082                                   null                      2313200
# 508083                                   null                      2313200
# 508084                                   null                      2313200
# 508085                                   null                      2313200
# 508086                                   null                      2313200
# 508087                                   null                      2313200
# 508088                                   null                      2313200
# 508089                                   null                      2313200
# 508090                                   null                      2313200
# 508091                                   null                      2313200
# 508092                                   null                      2313200
# 508093                                   null                      2313200
# 508094                                   null                      2313200
# 508095                                   null                      2313200
# 508096                                   null                      2313200
# 508097                                   null                      2313200
# 508098                                   null                      2313200
# 508099                                   null                      2313200
# 508100                                   null                      2313200
#
# [508101 rows x 31 columns]

# %%
# %%time
perf_ddf = gpu_load_performance_data(data_dir + '/perf-snappy.parquet/part.0.parquet')
# Out:
# CPU times: user 139 ms, sys: 0 ns, total: 139 ms
# Wall time: 140 ms

# %%
perf_ddf
# Out:
# <dask_cudf.DataFrame | 1 tasks | 1 npartitions>

# %%
perf_ddf.head()
# Out:
#             loan_id monthly_reporting_period                      servicer  \
# index
# 0      100000040778               01/01/2017                          None
# 1      100000040778               02/01/2017                          None
# 2      100000040778               03/01/2017                          None
# 3      100000040778               04/01/2017  NEW RESIDENTIAL MORTGAGE LLC
# 4      100000040778               05/01/2017                          None
#
#        interest_rate  current_actual_upb  loan_age  \
# index
# 0              3.875           234856.62       6.0
# 1              3.875           234470.90       7.0
# 2              3.875           234083.94       8.0
# 3              3.875           233720.67       9.0
# 4              3.875           233356.22      10.0
#
#        remaining_months_to_legal_maturity  adj_remaining_months_to_maturity  \
# index
# 0                                   354.0                             352.0
# 1                                   353.0                             351.0
# 2                                   352.0                             350.0
# 3                                   351.0                             349.0
# 4                                   350.0                             348.0
#
#       maturity_date      msa  ...  holding_taxes net_sale_proceeds  \
# index                         ...
# 0           07/2046  40140.0  ...           null              null
# 1           07/2046  40140.0  ...           null              null
# 2           07/2046  40140.0  ...           null              null
# 3           07/2046  40140.0  ...           null              null
# 4           07/2046  40140.0  ...           null              null
#
#       credit_enhancement_proceeds repurchase_make_whole_proceeds  \
# index
# 0                            null                           null
# 1                            null                           null
# 2                            null                           null
# 3                            null                           null
# 4                            null                           null
#
#       other_foreclosure_proceeds non_interest_bearing_upb  \
# index
# 0                           null                     null
# 1                           null                     null
# 2                           null                     null
# 3                           null                     null
# 4                           null                     null
#
#       principal_forgiveness_upb repurchase_make_whole_proceeds_flag  \
# index
# 0                          null                                None
# 1                          null                                None
# 2                          null                                None
# 3                          null                                None
# 4                          null                                None
#
#       foreclosure_principal_write_off_amount servicing_activity_indicator
# index
# 0                                       null                            N
# 1                                       null                            N
# 2                                       null                            N
# 3                                       null                            Y
# 4                                       null                            N
#
# [5 rows x 31 columns]

# %%
# %%time
# Read from files into GPU memory.
perf_ddf = perf_ddf.persist()
wait(perf_ddf)
# Out:
# CPU times: user 72.5 ms, sys: 6.39 ms, total: 78.9 ms
# Wall time: 76.4 ms

# %%
#perf_ddf.dask

# %%
# %%time
perf_ddf.head()
# Out:
# CPU times: user 111 ms, sys: 3.38 ms, total: 115 ms
# Wall time: 229 ms
#             loan_id monthly_reporting_period                      servicer  \
# index
# 0      100000040778               01/01/2017                          None
# 1      100000040778               02/01/2017                          None
# 2      100000040778               03/01/2017                          None
# 3      100000040778               04/01/2017  NEW RESIDENTIAL MORTGAGE LLC
# 4      100000040778               05/01/2017                          None
#
#        interest_rate  current_actual_upb  loan_age  \
# index
# 0              3.875           234856.62       6.0
# 1              3.875           234470.90       7.0
# 2              3.875           234083.94       8.0
# 3              3.875           233720.67       9.0
# 4              3.875           233356.22      10.0
#
#        remaining_months_to_legal_maturity  adj_remaining_months_to_maturity  \
# index
# 0                                   354.0                             352.0
# 1                                   353.0                             351.0
# 2                                   352.0                             350.0
# 3                                   351.0                             349.0
# 4                                   350.0                             348.0
#
#       maturity_date      msa  ...  holding_taxes net_sale_proceeds  \
# index                         ...
# 0           07/2046  40140.0  ...           null              null
# 1           07/2046  40140.0  ...           null              null
# 2           07/2046  40140.0  ...           null              null
# 3           07/2046  40140.0  ...           null              null
# 4           07/2046  40140.0  ...           null              null
#
#       credit_enhancement_proceeds repurchase_make_whole_proceeds  \
# index
# 0                            null                           null
# 1                            null                           null
# 2                            null                           null
# 3                            null                           null
# 4                            null                           null
#
#       other_foreclosure_proceeds non_interest_bearing_upb  \
# index
# 0                           null                     null
# 1                           null                     null
# 2                           null                     null
# 3                           null                     null
# 4                           null                     null
#
#       principal_forgiveness_upb repurchase_make_whole_proceeds_flag  \
# index
# 0                          null                                None
# 1                          null                                None
# 2                          null                                None
# 3                          null                                None
# 4                          null                                None
#
#       foreclosure_principal_write_off_amount servicing_activity_indicator
# index
# 0                                       null                            N
# 1                                       null                            N
# 2                                       null                            N
# 3                                       null                            Y
# 4                                       null                            N
#
# [5 rows x 31 columns]

# %%
# %%time
len(perf_ddf)
# Out:
# CPU times: user 6.03 ms, sys: 1.47 ms, total: 7.5 ms
# Wall time: 15.8 ms
# 508101

# %%
# %%time
perf_ddf.groupby(['servicer'])['interest_rate'].max().compute().head(2)
# Out:
# CPU times: user 97.3 ms, sys: 14.8 ms, total: 112 ms
# Wall time: 146 ms
# PROVIDENT FUNDING ASSOCIATES, L.P.    4.375
# FREEDOM MORTGAGE CORP.                5.000
# Name: interest_rate, dtype: float64

# %%
# %%time
perf_ddf.groupby(['servicer'])['interest_rate'].max().compute().head(2)
# Out:
# CPU times: user 101 ms, sys: 1.9 ms, total: 103 ms
# Wall time: 136 ms
# PROVIDENT FUNDING ASSOCIATES, L.P.    4.375
# FREEDOM MORTGAGE CORP.                5.000
# Name: interest_rate, dtype: float64

# %%
# %%time
perf_ddf.groupby(['servicer'])['interest_rate'].max().compute().head(2)
# Out:
# CPU times: user 104 ms, sys: 37 µs, total: 104 ms
# Wall time: 138 ms
# PROVIDENT FUNDING ASSOCIATES, L.P.    4.375
# FREEDOM MORTGAGE CORP.                5.000
# Name: interest_rate, dtype: float64

# %%
checksum = perf_ddf['loan_id'].sum().compute()
checksum
# Out:
# 62018971513503530

# %%
# compare to checksum from mortgage_etl_4.ipynb.
checksum - 6573355020803881490
# Out:
# -6511336049290377960

# %%
print(datetime.datetime.utcnow().isoformat())
# Out:
# 2019-11-23T01:37:40.137584

# %%
# !nvidia-smi
# Out:
# Sat Nov 23 01:37:40 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM3...  On   | 00000000:34:00.0 Off |                    0 |
# | N/A   36C    P0    70W / 350W |  13836MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM3...  On   | 00000000:36:00.0 Off |                    0 |
# | N/A   35C    P0    67W / 350W |  13712MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-SXM3...  On   | 00000000:39:00.0 Off |                    0 |
# | N/A   45C    P0    85W / 350W |  13198MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-SXM3...  On   | 00000000:3B:00.0 Off |                    0 |
# | N/A   43C    P0    72W / 350W |  13720MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  Tesla V100-SXM3...  On   | 00000000:57:00.0 Off |                    0 |
# | N/A   37C    P0    82W / 350W |  13480MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  Tesla V100-SXM3...  On   | 00000000:59:00.0 Off |                    0 |
# | N/A   42C    P0    88W / 350W |  14110MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  Tesla V100-SXM3...  On   | 00000000:5C:00.0 Off |                    0 |
# | N/A   36C    P0    80W / 350W |  13372MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  Tesla V100-SXM3...  On   | 00000000:5E:00.0 Off |                    0 |
# | N/A   44C    P0    82W / 350W |  12488MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   8  Tesla V100-SXM3...  On   | 00000000:B7:00.0 Off |                    0 |
# | N/A   34C    P0    84W / 350W |  13670MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   9  Tesla V100-SXM3...  On   | 00000000:B9:00.0 Off |                    0 |
# | N/A   38C    P0    83W / 350W |  13202MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |  10  Tesla V100-SXM3...  On   | 00000000:BC:00.0 Off |                    0 |
# | N/A   44C    P0    84W / 350W |  13550MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |  11  Tesla V100-SXM3...  On   | 00000000:BE:00.0 Off |                    0 |
# | N/A   44C    P0    87W / 350W |  12936MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |  12  Tesla V100-SXM3...  On   | 00000000:E0:00.0 Off |                    0 |
# | N/A   35C    P0    66W / 350W |  13052MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |  13  Tesla V100-SXM3...  On   | 00000000:E2:00.0 Off |                    0 |
# | N/A   37C    P0    84W / 350W |  13766MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |  14  Tesla V100-SXM3...  On   | 00000000:E5:00.0 Off |                    0 |
# | N/A   44C    P0    85W / 350W |  13874MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |  15  Tesla V100-SXM3...  On   | 00000000:E7:00.0 Off |                    0 |
# | N/A   42C    P0    82W / 350W |  13376MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
